# %%
from collections import defaultdict
import math
import numpy as np
from numpy import ma
import datetime, time
from datetime import datetime
import netCDF4
from netCDF4 import Dataset, num2date
from scipy.interpolate import griddata

import halem
import halem.Mesh_maker as Mesh_maker
import halem.Functions as Functions
import halem.Calc_path as Calc_path
import halem.Flow_class as Flow_class

import matplotlib.pyplot as plt
plt.style.use('ggplot')
% matplotlib inline

import os
from cartopy import config
import cartopy.crs as ccrs
import cartopy.feature as cfeature

# %% [markdown]
# # User defined values

# %%
nl = (1,1)
dx_min = 0.05
blend = 0.8


number_of_neighbor_layers = 2
vship = vship = np.array([[3,4,5,16], [5,6,7,18]])
WD_min = 1.5
Load_flow = Flow_class.flow_2D_FM_05nm


name_textfile_flow = 'D:/DCSM-FM/A06_pieter/DCSM-FM_0_5nm_0017_map.nc'
name_textfile_save = 'test'

# %%
def compute_cost(week_rate, fuel_rate):
    second_rate = week_rate/7/24/60/60
    return lambda travel_time, speed: (travel_time*second_rate + fuel_rate*travel_time * speed**3)

# %%
start_time = time.time()

graph = Mesh_maker.Graph_flow_model(name_textfile_flow, 
                                    dx_min, 
                                    blend, 
                                    nl, 
                                    number_of_neighbor_layers, 
                                    vship, 
                                    Load_flow, 
                                    WD_min,
                                    compute_cost(700_000, 0.0005),
                                    halem.Flow_class.nodes_on_land_Waddensea
                                   )

stop_time = time.time()
computation_time = stop_time - start_time
print("the computational time is:", round(computation_time,2), "sec")
# Out:
# 1/4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-18cc4fc6cdd1> in <module>()
#      10                                     WD_min,
#      11                                     compute_cost(700_000, 0.0005),
# ---> 12                                     halem.Flow_class.nodes_on_land_Waddensea
#      13                                    )
#      14
#
# c:\users\d4l\onedrive - van oord\route_optimization_in_dynamic_currents\halem\Mesh_maker.py in __init__(self, name_textfile_flow, dx_min, blend, nl, number_of_neighbor_layers, vship, Load_flow, WD_min, compute_cost, nodes_on_land)
#     186
#     187         'Calculate nodes and flow conditions in nodes'
# --> 188         self.nodes_index, self.LS = Get_nodes(flow, nl, dx_min, blend)
#     189
#     190         nodes = flow.nodes[self.nodes_index]
#
# c:\users\d4l\onedrive - van oord\route_optimization_in_dynamic_currents\halem\Mesh_maker.py in Get_nodes(flow, nl, dx_min, blend)
#     160             q = int(0)
#     161             qq +=1
# --> 162         LS_node = Length_scale(i, flow, blend, nl)
#     163         LS.append(LS_node)
#     164         closest_nod = closest_node(i, new_nodes, nodes)
#
# c:\users\d4l\onedrive - van oord\route_optimization_in_dynamic_currents\halem\Mesh_maker.py in Length_scale(node, flow, blend, nl)
#     140         return 1
#     141
# --> 142     curl = abs(curl_func(node, flow))
#     143
#     144     LS_c = ma.array(1 / (1+curl) ** nl[0])
#
# c:\users\d4l\onedrive - van oord\route_optimization_in_dynamic_currents\halem\Mesh_maker.py in curl_func(node, flow)
#     124         v = flow.v[i,nb]
#     125         dudy = float(slope(xs,ys,u)[1])
# --> 126         dvdx = float(slope(xs,ys,v)[0])
#     127         DUDY.append(dudy)
#     128         DVDX.append(dvdx)
#
# c:\users\d4l\onedrive - van oord\route_optimization_in_dynamic_currents\halem\Mesh_maker.py in slope(xs, ys, zs)
#     107     b = np.matrix(tmp_b).T
#     108     A = np.matrix(tmp_A)
# --> 109     fit = (A.T * A).I * A.T * b
#     110     errors = b - A * fit
#     111     residual = np.linalg.norm(errors)
#
# C:\ProgramData\Anaconda3\lib\site-packages\numpy\matrixlib\defmatrix.py in __mul__(self, other)
#     307         if isinstance(other, (N.ndarray, list, tuple)) :
#     308             # This promotes 1-D vectors to row vectors
# --> 309             return N.dot(self, asmatrix(other))
#     310         if isscalar(other) or not hasattr(other, '__rmul__') :
#     311             return N.dot(self, other)
#
# KeyboardInterrupt:

# %%
RODFF.save_object(graph, name_textfile_save)

# %%
np.savetxt('D:/Roadmaps/nodes_inex(Rm_DCSM_FM_05nm_WDmin=1.5,nl=(0.9, 1)).csv', graph.nodes_index)

# %% [markdown]
# # Plots

# %%
fig = plt.figure(figsize=(15, 15))
ax = plt.axes(projection=ccrs.Mercator())

#cval = np.arange(0,1, 0.01)
#plt.contourf(x_r,y_r, LS_r, cval)
#cbar = plt.colorbar()

plt.triplot(graph.nodes[:,1], graph.nodes[:,0], graph.tria.simplices, linewidth = 0.5, color = 'k', label = 'Delauney edges')

# %%
curl = np.arange(0,100,0.001)
def LS(nonlinearity):
    LS = 1/(1+curl)**nonlinearity
    return LS

fig = plt.figure()
fig.set_size_inches(6, 6)
plt.semilogx(curl, LS(0), label = r'$\beta =  0$')
plt.semilogx(curl, LS(1), label = r'$\beta =  1$')
plt.semilogx(curl, LS(5), label = r'$\beta =  5$')
plt.semilogx(curl, LS(10), label = r'$\beta =  10$')
plt.semilogx(curl, LS(20), label = r'$\beta =  20$')
plt.semilogx(curl, LS(np.inf), label = r'$\beta =  infinite$')

plt.title("influence of the nonlinearity on the length scale, \n LS = 1/(1+curl)^nonlinearity")
plt.xlabel("Absolute value of the curl or magnitude of the flow (on log scale)")
plt.ylabel("Length scale for different nonlinearities")

plt.legend(loc = 'best')
#plt.savefig("Influence_of_nonlinearity", dpi = 200)
plt.show()

# %%
x_r = np.arange(4.5,5.5, 0.001)
y_r = np.arange(53,54, 0.01)
y_r, x_r = np.meshgrid(y_r,x_r)

WD_r = griddata((graph.nodes[:,1], graph.nodes[:,0]), graph.WD[:,1], (x_r, y_r), method= 'linear')

# %%
fig = plt.figure(figsize=(15, 15))
ax = plt.axes(projection=ccrs.Mercator())

cval = np.arange(1.5,40,1)
plt.contourf(x_r,y_r,WD_r, cval, transform=ccrs.PlateCarree())
#cbar = plt.colorbar()

ax.coastlines(resolution='10m', color='black', linewidth=3)
ax.gridlines(color = 'grey', zorder = 3)
ax.add_feature(cfeature.NaturalEarthFeature('physical', 'land', '10m', edgecolor='face', facecolor='palegoldenrod'))

plt.plot(graph.nodes[550][1],graph.nodes[550][0], 'ro', transform=ccrs.PlateCarree())
plt.show()


print(len(graph.nodes)**0.5)
